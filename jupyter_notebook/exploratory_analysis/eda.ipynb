# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd
data='/home/luis/github/pdg/base_data.csv'
try:
    df = pd.read_csv(data)
    display(df.head())
except FileNotFoundError:
    print("Error: 'flair_df.csv' not found. Please ensure the file exists in the current directory.")
    df = None # Assign None to df in case of error
except pd.errors.ParserError:
    print("Error: Could not parse 'flair_df.csv'. Please check the file format.")
    df = None # Assign None to df in case of error
# Out:
#    Unnamed: 0.1                      Unnamed: 0  \
# 0             0  Segmentation_segment_Segment_1
# 1             0  Segmentation_segment_Segment_1
# 2             0  Segmentation_segment_Segment_1
# 3             0  Segmentation_segment_Segment_1
# 4             0  Segmentation_segment_Segment_1
#
#   PyRadiomics/Versions/diagnostics Numpy/Versions/diagnostics  \
# 0            v3.1.0.post2+g146e3bd                     1.26.4
# 1            v3.1.0.post2+g146e3bd                     1.26.4
# 2            v3.1.0.post2+g146e3bd                     1.26.4
# 3            v3.1.0.post2+g146e3bd                     1.26.4
# 4            v3.1.0.post2+g146e3bd                     1.26.4
#
#   SimpleITK/Versions/diagnostics PyWavelet/Versions/diagnostics  \
# 0                2.4.0rc2.dev213                          1.6.0
# 1                2.4.0rc2.dev213                          1.6.0
# 2                2.4.0rc2.dev213                          1.6.0
# 3                2.4.0rc2.dev213                          1.6.0
# 4                2.4.0rc2.dev213                          1.6.0
#
#   Python/Versions/diagnostics  \
# 0                      3.9.10
# 1                      3.9.10
# 2                      3.9.10
# 3                      3.9.10
# 4                      3.9.10
#
#                   Settings/Configuration/diagnostics  \
# 0  {'minimumROIDimensions': 2, 'minimumROISize': ...
# 1  {'minimumROIDimensions': 2, 'minimumROISize': ...
# 2  {'minimumROIDimensions': 2, 'minimumROISize': ...
# 3  {'minimumROIDimensions': 2, 'minimumROISize': ...
# 4  {'minimumROIDimensions': 2, 'minimumROISize': ...
#
#   EnabledImageTypes/Configuration/diagnostics  \
# 0                            {'Original': {}}
# 1                            {'Original': {}}
# 2                            {'Original': {}}
# 3                            {'Original': {}}
# 4                            {'Original': {}}
#
#             Hash/Image-original/diagnostics  ... Contrast/ngtdm/original  \
# 0  1ffbffc2fc605b7d5ef1c3b2a790d8a98c93f4dd  ...                0.021313
# 1  7b22c2b1767617dc0d3db815ae703599ce4e1f62  ...                0.028828
# 2  87a8f9a8fefc50209701c5ec696c5e72e40c0e15  ...                0.017710
# 3  efd706b8f24a144f47c8533ddda2b644b7f4896a  ...                0.021700
# 4  b4dd0e54af5ed18fe1f1b6f526f1fbd8b1b4d60a  ...                0.037276
#
#    Strength/ngtdm/original  x.BoundingBox/Mask-original/diagnostics  \
# 0                 0.109595                                     88.0
# 1                 0.088929                                    152.0
# 2                 0.130043                                     68.0
# 3                 0.228678                                     72.0
# 4                 0.891463                                    104.0
#
#    y.BoundingBox/Mask-original/diagnostics  \
# 0                                    138.0
# 1                                    112.0
# 2                                    104.0
# 3                                    150.0
# 4                                    181.0
#
#    z.BoundingBox/Mask-original/diagnostics  \
# 0                                    124.0
# 1                                     92.0
# 2                                     53.0
# 3                                     45.0
# 4                                     10.0
#
#    BoundingBox/Mask-original/diagnostics  \
# 0                                   1776
# 1                                   3431
# 2                                   4416
# 3                                   2288
# 4                                   2250
#
#   x.CenterOfMassIndex/Mask-original/diagnostics  \
# 0                                    105.497619
# 1                                    174.448790
# 2                                     90.755240
# 3                                     97.611413
# 4                                    127.684988
#
#    y.CenterOfMassIndex/Mask-original/diagnostics  \
# 0                                     161.988889
# 1                                     149.808566
# 2                                     152.673859
# 3                                     171.559783
# 4                                     202.115248
#
#    z.CenterOfMassIndex/Mask-original/diagnostics  highGrade
# 0                                          124.0       True
# 1                                           92.0       True
# 2                                           53.0       True
# 3                                           45.0       True
# 4                                           10.0       True
#
# [5 rows x 123 columns]

# %% [markdown]
# ### Basic preprocessing

# %%
for col in df.columns:
    print(col)
# Out:
# Unnamed: 0.1
# Unnamed: 0
# PyRadiomics/Versions/diagnostics
# Numpy/Versions/diagnostics
# SimpleITK/Versions/diagnostics
# PyWavelet/Versions/diagnostics
# Python/Versions/diagnostics
# Settings/Configuration/diagnostics
# EnabledImageTypes/Configuration/diagnostics
# Hash/Image-original/diagnostics
# Dimensionality/Image-original/diagnostics
# Spacing/Image-original/diagnostics
# Size/Image-original/diagnostics
# Mean/Image-original/diagnostics
# Minimum/Image-original/diagnostics
# Maximum/Image-original/diagnostics
# Hash/Mask-original/diagnostics
# Spacing/Mask-original/diagnostics
# Size/Mask-original/diagnostics
# VoxelNum/Mask-original/diagnostics
# VolumeNum/Mask-original/diagnostics
# CenterOfMass/Mask-original/diagnostics
# 10Percentile/firstorder/original
# 90Percentile/firstorder/original
# Energy/firstorder/original
# Entropy/firstorder/original
# InterquartileRange/firstorder/original
# Kurtosis/firstorder/original
# Maximum/firstorder/original
# MeanAbsoluteDeviation/firstorder/original
# Mean/firstorder/original
# Median/firstorder/original
# Minimum/firstorder/original
# Range/firstorder/original
# RobustMeanAbsoluteDeviation/firstorder/original
# RootMeanSquared/firstorder/original
# Skewness/firstorder/original
# TotalEnergy/firstorder/original
# Uniformity/firstorder/original
# Variance/firstorder/original
# Autocorrelation/glcm/original
# ClusterProminence/glcm/original
# ClusterShade/glcm/original
# ClusterTendency/glcm/original
# Contrast/glcm/original
# Correlation/glcm/original
# DifferenceAverage/glcm/original
# DifferenceEntropy/glcm/original
# DifferenceVariance/glcm/original
# Id
# Idm/glcm/original
# Idmn/glcm/original
# Idn/glcm/original
# Imc1/glcm/original
# Imc2/glcm/original
# InverseVariance/glcm/original
# JointAverage/glcm/original
# JointEnergy/glcm/original
# JointEntropy/glcm/original
# MCC/glcm/original
# MaximumProbability/glcm/original
# SumAverage/glcm/original
# SumEntropy/glcm/original
# SumSquares/glcm/original
# DependenceEntropy/gldm/original
# DependenceNonUniformity/gldm/original
# DependenceNonUniformityNormalized/gldm/original
# DependenceVariance/gldm/original
# GrayLevelNonUniformity/gldm/original
# GrayLevelVariance/gldm/original
# HighGrayLevelEmphasis/gldm/original
# LargeDependenceEmphasis/gldm/original
# LargeDependenceHighGrayLevelEmphasis/gldm/original
# LargeDependenceLowGrayLevelEmphasis/gldm/original
# LowGrayLevelEmphasis/gldm/original
# SmallDependenceEmphasis/gldm/original
# SmallDependenceHighGrayLevelEmphasis/gldm/original
# SmallDependenceLowGrayLevelEmphasis/gldm/original
# GrayLevelNonUniformity/glrlm/original
# GrayLevelNonUniformityNormalized/glrlm/original
# GrayLevelVariance/glrlm/original
# HighGrayLevelRunEmphasis/glrlm/original
# LongRunEmphasis/glrlm/original
# LongRunHighGrayLevelEmphasis/glrlm/original
# LongRunLowGrayLevelEmphasis/glrlm/original
# LowGrayLevelRunEmphasis/glrlm/original
# RunEntropy/glrlm/original
# RunLengthNonUniformity/glrlm/original
# RunLengthNonUniformityNormalized/glrlm/original
# RunPercentage/glrlm/original
# RunVariance/glrlm/original
# ShortRunEmphasis/glrlm/original
# ShortRunHighGrayLevelEmphasis/glrlm/original
# ShortRunLowGrayLevelEmphasis/glrlm/original
# GrayLevelNonUniformity/glszm/original
# GrayLevelNonUniformityNormalized/glszm/original
# GrayLevelVariance/glszm/original
# HighGrayLevelZoneEmphasis/glszm/original
# LargeAreaEmphasis/glszm/original
# LargeAreaHighGrayLevelEmphasis/glszm/original
# LargeAreaLowGrayLevelEmphasis/glszm/original
# LowGrayLevelZoneEmphasis/glszm/original
# SizeZoneNonUniformity/glszm/original
# SizeZoneNonUniformityNormalized/glszm/original
# SmallAreaEmphasis/glszm/original
# SmallAreaHighGrayLevelEmphasis/glszm/original
# SmallAreaLowGrayLevelEmphasis/glszm/original
# ZoneEntropy/glszm/original
# ZonePercentage/glszm/original
# ZoneVariance/glszm/original
# Busyness/ngtdm/original
# Coarseness/ngtdm/original
# Complexity/ngtdm/original
# Contrast/ngtdm/original
# Strength/ngtdm/original
# x.BoundingBox/Mask-original/diagnostics
# y.BoundingBox/Mask-original/diagnostics
# z.BoundingBox/Mask-original/diagnostics
# BoundingBox/Mask-original/diagnostics
# x.CenterOfMassIndex/Mask-original/diagnostics
# y.CenterOfMassIndex/Mask-original/diagnostics
# z.CenterOfMassIndex/Mask-original/diagnostics
# highGrade

# %%
df.set_index('Id', inplace=True)
df.shape
# Out:
# (128, 122)

# %%
# HIGH and LOW grades balance

print('LOW: ', df[df['highGrade']==False].shape[0]/df.shape[0]) 

print('HIGH: ', df[df['highGrade']==True].shape[0]/df.shape[0])
# Out:
# LOW:  0.2265625
# HIGH:  0.7734375

# %%
# separates object columns containing mainly metadata from 
# the nuemrical columns containing actual radiomic values

df_meta=df.select_dtypes(include=['object'])
df.drop(columns = df_meta.columns, inplace=True)
df.shape
# Out:
# (128, 111)

# %%
df_meta.head()
# Out:
#                               Unnamed: 0 PyRadiomics/Versions/diagnostics  \
# Id
# 0.783201  Segmentation_segment_Segment_1            v3.1.0.post2+g146e3bd
# 0.729412  Segmentation_segment_Segment_1            v3.1.0.post2+g146e3bd
# 0.662097  Segmentation_segment_Segment_1            v3.1.0.post2+g146e3bd
# 0.782308  Segmentation_segment_Segment_1            v3.1.0.post2+g146e3bd
# 0.585369  Segmentation_segment_Segment_1            v3.1.0.post2+g146e3bd
#
#          Numpy/Versions/diagnostics SimpleITK/Versions/diagnostics  \
# Id
# 0.783201                     1.26.4                2.4.0rc2.dev213
# 0.729412                     1.26.4                2.4.0rc2.dev213
# 0.662097                     1.26.4                2.4.0rc2.dev213
# 0.782308                     1.26.4                2.4.0rc2.dev213
# 0.585369                     1.26.4                2.4.0rc2.dev213
#
#          PyWavelet/Versions/diagnostics Python/Versions/diagnostics  \
# Id
# 0.783201                          1.6.0                      3.9.10
# 0.729412                          1.6.0                      3.9.10
# 0.662097                          1.6.0                      3.9.10
# 0.782308                          1.6.0                      3.9.10
# 0.585369                          1.6.0                      3.9.10
#
#                          Settings/Configuration/diagnostics  \
# Id
# 0.783201  {'minimumROIDimensions': 2, 'minimumROISize': ...
# 0.729412  {'minimumROIDimensions': 2, 'minimumROISize': ...
# 0.662097  {'minimumROIDimensions': 2, 'minimumROISize': ...
# 0.782308  {'minimumROIDimensions': 2, 'minimumROISize': ...
# 0.585369  {'minimumROIDimensions': 2, 'minimumROISize': ...
#
#          EnabledImageTypes/Configuration/diagnostics  \
# Id
# 0.783201                            {'Original': {}}
# 0.729412                            {'Original': {}}
# 0.662097                            {'Original': {}}
# 0.782308                            {'Original': {}}
# 0.585369                            {'Original': {}}
#
#                    Hash/Image-original/diagnostics  \
# Id
# 0.783201  1ffbffc2fc605b7d5ef1c3b2a790d8a98c93f4dd
# 0.729412  7b22c2b1767617dc0d3db815ae703599ce4e1f62
# 0.662097  87a8f9a8fefc50209701c5ec696c5e72e40c0e15
# 0.782308  efd706b8f24a144f47c8533ddda2b644b7f4896a
# 0.585369  b4dd0e54af5ed18fe1f1b6f526f1fbd8b1b4d60a
#
#          Dimensionality/Image-original/diagnostics  \
# Id
# 0.783201                                        3D
# 0.729412                                        3D
# 0.662097                                        3D
# 0.782308                                        3D
# 0.585369                                        3D
#
#                     Hash/Mask-original/diagnostics
# Id
# 0.783201  731b2f2113593782807db4b12219c2641780e152
# 0.729412  fa7105c5cad49bbeda063571fc091b6740bd8045
# 0.662097  4181a8a9f56aa706f630c2ec846e2b2ef8f29a0a
# 0.782308  1f79e01ce7d0e1d9fba7008e5ecfb3d13ca6f1ad
# 0.585369  5e41117b1288a4f7b6599cccb046a09621df0248

# %% [markdown]
# ### Statistics

# %%
### Numerical Statistiques

# Check for missing values
print("Missing values per column:\n", df.isnull().sum())

# Check for duplicated rows
print(f"\nNumber of duplicated rows: {df.duplicated().sum()}")

# Summary statistics
print("\nSummary Statistics:\n", df.describe())


correlation_with_target = df.corr()['highGrade'].drop('highGrade').sort_values(ascending=False)

# Plot
plt.figure(figsize=(10, 6))
correlation_with_target.plot(kind='bar', color='skyblue')
plt.title('Correlation of Features with Target: highGrade')
plt.ylabel('Correlation coefficient')
plt.tight_layout()
plt.show()


'''
# Histograms of numerical features
df.hist(figsize=(20, 20), bins=50)
plt.suptitle("Histograms of Numerical Features")
plt.show()

# Pairplot for a subset of features
sns.pairplot(df[['Strength', 'Size.a', 'Size.b', 'Size.c']], diag_kind="kde")
plt.suptitle("Pairplot of Selected Features")
plt.show()'''
# Out:
# Missing values per column:
#  Unnamed: 0.1                                     0
# Spacing/Image-original/diagnostics               0
# Size/Image-original/diagnostics                  0
# Mean/Image-original/diagnostics                  0
# Minimum/Image-original/diagnostics               0
#                                                 ..
# BoundingBox/Mask-original/diagnostics            0
# x.CenterOfMassIndex/Mask-original/diagnostics    0
# y.CenterOfMassIndex/Mask-original/diagnostics    0
# z.CenterOfMassIndex/Mask-original/diagnostics    0
# highGrade                                        0
# Length: 111, dtype: int64
#
# Number of duplicated rows: 0
#
# Summary Statistics:
#         Unnamed: 0.1  Spacing/Image-original/diagnostics  \
# count         128.0                          128.000000
# mean            0.0                            2.246744
# std             0.0                            1.699386
# min             0.0                            0.181618
# 25%             0.0                            0.953674
# 50%             0.0                            1.210785
# 75%             0.0                            3.357910
# max             0.0                            5.722046
#
#        Size/Image-original/diagnostics  Mean/Image-original/diagnostics  \
# count                     1.280000e+02                       128.000000
# mean                      9.329189e+06                        62.688284
# std                       1.137356e+07                        46.817455
# min                       1.277952e+06                         7.929055
# 25%                       1.996800e+06                        18.825764
# 50%                       6.193152e+06                        47.553785
# 75%                       1.153434e+07                       110.971412
# max                       5.452595e+07                       213.624087
#
#        Minimum/Image-original/diagnostics  Maximum/Image-original/diagnostics  \
# count                               128.0                          128.000000
# mean                                  0.0                          695.726562
# std                                   0.0                          548.128264
# min                                   0.0                           94.000000
# 25%                                   0.0                          260.750000
# 50%                                   0.0                          607.500000
# 75%                                   0.0                          979.500000
# max                                   0.0                         3761.000000
#
#        Spacing/Mask-original/diagnostics  Size/Mask-original/diagnostics  \
# count                         128.000000                    1.280000e+02
# mean                            2.246744                    9.329189e+06
# std                             1.699386                    1.137356e+07
# min                             0.181618                    1.277952e+06
# 25%                             0.953674                    1.996800e+06
# 50%                             1.210785                    6.193152e+06
# 75%                             3.357910                    1.153434e+07
# max                             5.722046                    5.452595e+07
#
#        VoxelNum/Mask-original/diagnostics  \
# count                          128.000000
# mean                          5614.796875
# std                           5627.922767
# min                            223.000000
# 25%                           2469.250000
# 50%                           3655.000000
# 75%                           6481.500000
# max                          28455.000000
#
#        VolumeNum/Mask-original/diagnostics  ...  Complexity/ngtdm/original  \
# count                           128.000000  ...                 128.000000
# mean                              1.023438  ...                 134.488339
# std                               0.197019  ...                 249.681818
# min                               1.000000  ...                   0.292214
# 25%                               1.000000  ...                  11.518628
# 50%                               1.000000  ...                  57.746858
# 75%                               1.000000  ...                 168.211977
# max                               3.000000  ...                2385.861756
#
#        Contrast/ngtdm/original  Strength/ngtdm/original  \
# count               128.000000               128.000000
# mean                  0.029348                 1.355160
# std                   0.028755                 3.107654
# min                   0.003004                 0.003047
# 25%                   0.013734                 0.132153
# 50%                   0.020115                 0.563137
# 75%                   0.039526                 1.321633
# max                   0.225191                27.495146
#
#        x.BoundingBox/Mask-original/diagnostics  \
# count                               128.000000
# mean                                117.734375
# std                                  53.665262
# min                                  33.000000
# 25%                                  74.000000
# 50%                                 119.000000
# 75%                                 142.000000
# max                                 293.000000
#
#        y.BoundingBox/Mask-original/diagnostics  \
# count                               128.000000
# mean                                121.359375
# std                                  49.764759
# min                                  46.000000
# 25%                                  92.500000
# 50%                                 113.500000
# 75%                                 138.000000
# max                                 294.000000
#
#        z.BoundingBox/Mask-original/diagnostics  \
# count                               128.000000
# mean                                 55.726562
# std                                  47.708220
# min                                   6.000000
# 25%                                  13.000000
# 50%                                  19.000000
# 75%                                 101.250000
# max                                 167.000000
#
#        BoundingBox/Mask-original/diagnostics  \
# count                             128.000000
# mean                             7790.835938
# std                              7729.379668
# min                               440.000000
# 25%                              3294.000000
# 50%                              5144.000000
# 75%                              8625.000000
# max                             38250.000000
#
#        x.CenterOfMassIndex/Mask-original/diagnostics  \
# count                                     128.000000
# mean                                      150.931765
# std                                        60.671140
# min                                        73.283755
# 25%                                       105.258782
# 50%                                       143.499410
# 75%                                       170.655347
# max                                       344.620776
#
#        y.CenterOfMassIndex/Mask-original/diagnostics  \
# count                                     128.000000
# mean                                      167.851954
# std                                        58.682147
# min                                        83.899043
# 25%                                       125.410023
# 50%                                       157.043145
# 75%                                       189.695393
# max                                       358.662550
#
#        z.CenterOfMassIndex/Mask-original/diagnostics
# count                                     128.000000
# mean                                       55.741804
# std                                        47.703088
# min                                         6.000000
# 25%                                        13.000000
# 50%                                        19.000000
# 75%                                       101.250000
# max                                       167.000000
#
# [8 rows x 110 columns]
# '\n# Histograms of numerical features\ndf.hist(figsize=(20, 20), bins=50)\nplt.suptitle("Histograms of Numerical Features")\nplt.show()\n\n# Pairplot for a subset of features\nsns.pairplot(df[[\'Strength\', \'Size.a\', \'Size.b\', \'Size.c\']], diag_kind="kde")\nplt.suptitle("Pairplot of Selected Features")\nplt.show()'

# %%
# Get top 30 features by absolute correlation
top = correlation_with_target.abs().sort_values(ascending=False).head(15)

print(top)

# Retrieve original signed correlations for those top 30 features
top_signed = correlation_with_target[top.index]


# Plot
plt.figure(figsize=(16, 12))  # Bigger figure size
top_signed.sort_values().plot(
    kind='barh',
    color='cornflowerblue',
    edgecolor='black'
)

plt.title('Most Correlated Features with highGrade', fontsize=20)
plt.xlabel('Correlation Coefficient', fontsize=16)
plt.ylabel('Features', fontsize=16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='x', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# y.CenterOfMassIndex/Mask-original/diagnostics         0.232201
# VolumeNum/Mask-original/diagnostics                   0.220661
# Coarseness/ngtdm/original                             0.211553
# SmallDependenceLowGrayLevelEmphasis/gldm/original     0.211097
# y.BoundingBox/Mask-original/diagnostics               0.207610
# RunLengthNonUniformity/glrlm/original                 0.172801
# GrayLevelNonUniformity/glszm/original                 0.169387
# GrayLevelNonUniformity/glrlm/original                 0.146192
# LargeDependenceHighGrayLevelEmphasis/gldm/original    0.138135
# Energy/firstorder/original                            0.137992
# ZoneEntropy/glszm/original                            0.135012
# VoxelNum/Mask-original/diagnostics                    0.129865
# TotalEnergy/firstorder/original                       0.129061
# Maximum/Image-original/diagnostics                    0.127572
# Idn/glcm/original                                     0.127063
# Name: highGrade, dtype: float64

# %%
df_cp=df.copy()

cols_to_drop=[col for col in df.columns if col not in top.index]
cols_to_drop
df.drop(columns=cols_to_drop, inplace=True)
df['highGrade']=df_cp['highGrade']
df
# Out:
#           Maximum/Image-original/diagnostics  \
# Id
# 0.783201                               237.0
# 0.729412                               253.0
# 0.662097                               270.0
# 0.782308                               314.0
# 0.585369                               981.0
# ...                                      ...
# 0.774391                               277.0
# 0.720461                               325.0
# 0.601364                              1411.0
# 0.729605                               604.0
# 0.699646                              1108.0
#
#           VoxelNum/Mask-original/diagnostics  \
# Id
# 0.783201                                1260
# 0.729412                                2685
# 0.662097                                3244
# 0.782308                                1840
# 0.585369                                1692
# ...                                      ...
# 0.774391                                1889
# 0.720461                                3652
# 0.601364                                6199
# 0.729605                                7085
# 0.699646                               12171
#
#           VolumeNum/Mask-original/diagnostics  Energy/firstorder/original  \
# Id
# 0.783201                                    1                1.115748e+07
# 0.729412                                    1                3.206621e+07
# 0.662097                                    1                5.772904e+07
# 0.782308                                    1                5.558937e+07
# 0.585369                                    1                5.079416e+08
# ...                                       ...                         ...
# 0.774391                                    1                2.601654e+07
# 0.720461                                    1                7.703724e+07
# 0.601364                                    1                3.315145e+09
# 0.729605                                    1                7.963674e+08
# 0.699646                                    1                3.742599e+09
#
#           TotalEnergy/firstorder/original  Idn/glcm/original  \
# Id
# 0.783201                     1.115748e+07           0.935386
# 0.729412                     3.206621e+07           0.934436
# 0.662097                     5.505470e+07           0.934934
# 0.782308                     4.038406e+07           0.951514
# 0.585369                     1.705622e+09           0.949190
# ...                                   ...                ...
# 0.774391                     2.481130e+07           0.946634
# 0.720461                     7.946346e+07           0.942016
# 0.601364                     1.113196e+10           0.967871
# 0.729605                     2.468428e+09           0.966738
# 0.699646                     4.909106e+09           0.978241
#
#           LargeDependenceHighGrayLevelEmphasis/gldm/original  \
# Id
# 0.783201                                         652.826984
# 0.729412                                         611.548231
# 0.662097                                         660.159679
# 0.782308                                        1143.141304
# 0.585369                                        3356.104019
# ...                                                     ...
# 0.774391                                         914.722605
# 0.720461                                        1141.659639
# 0.601364                                        9096.525085
# 0.729605                                        1863.377417
# 0.699646                                       12246.326103
#
#           SmallDependenceLowGrayLevelEmphasis/gldm/original  \
# Id
# 0.783201                                           0.006669
# 0.729412                                           0.009179
# 0.662097                                           0.008074
# 0.782308                                           0.006239
# 0.585369                                           0.001814
# ...                                                     ...
# 0.774391                                           0.005010
# 0.720461                                           0.009901
# 0.601364                                           0.000652
# 0.729605                                           0.004621
# 0.699646                                           0.000532
#
#           GrayLevelNonUniformity/glrlm/original  \
# Id
# 0.783201                             158.590584
# 0.729412                             293.777441
# 0.662097                             435.126064
# 0.782308                             158.487887
# 0.585369                             149.244465
# ...                                         ...
# 0.774391                             218.499407
# 0.720461                             336.608660
# 0.601364                             434.953676
# 0.729605                             336.479787
# 0.699646                             425.881185
#
#           RunLengthNonUniformity/glrlm/original  \
# Id
# 0.783201                             175.099687
# 0.729412                             546.590764
# 0.662097                             961.241702
# 0.782308                             273.906764
# 0.585369                             696.367524
# ...                                         ...
# 0.774391                             273.046673
# 0.720461                             778.238077
# 0.601364                            2394.525537
# 0.729605                            1410.298294
# 0.699646                            2976.089706
#
#           GrayLevelNonUniformity/glszm/original  ZoneEntropy/glszm/original  \
# Id
# 0.783201                              17.388889                    4.696937
# 0.729412                              50.100719                    5.422075
# 0.662097                              85.296015                    5.453404
# 0.782308                              27.150943                    5.047446
# 0.585369                              44.787419                    5.763565
# ...                                         ...                         ...
# 0.774391                              26.022901                    5.046687
# 0.720461                              65.146868                    5.347434
# 0.601364                             126.697412                    6.406543
# 0.729605                              58.675963                    6.840655
# 0.699646                              79.179894                    7.331360
#
#           Coarseness/ngtdm/original  y.BoundingBox/Mask-original/diagnostics  \
# Id
# 0.783201                   0.007719                                    138.0
# 0.729412                   0.004074                                    112.0
# 0.662097                   0.002515                                    104.0
# 0.782308                   0.006769                                    150.0
# 0.585369                   0.006528                                    181.0
# ...                             ...                                      ...
# 0.774391                   0.005374                                    108.0
# 0.720461                   0.003218                                     61.0
# 0.601364                   0.002340                                    137.0
# 0.729605                   0.003548                                    126.0
# 0.699646                   0.003712                                    152.0
#
#           y.CenterOfMassIndex/Mask-original/diagnostics  highGrade
# Id
# 0.783201                                     161.988889       True
# 0.729412                                     149.808566       True
# 0.662097                                     152.673859       True
# 0.782308                                     171.559783       True
# 0.585369                                     202.115248       True
# ...                                                 ...        ...
# 0.774391                                     132.161461      False
# 0.720461                                     101.386911      False
# 0.601364                                     188.893209       True
# 0.729605                                     186.333945      False
# 0.699646                                     241.988579       True
#
# [128 rows x 16 columns]

# %% [markdown]
# ## Outliers

# %%
#getting targets
targets=df[['highGrade']]

df.drop(columns=['highGrade'], inplace=True)

# %%
df_cp=df.copy()

# %% [markdown]
# ### General Outliers

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
multiplier=3
outliers_count = ((df < (Q1 - multiplier* IQR)) | (df > (Q3 + multiplier* IQR))).sum()

totalOut = sum(x > 0 for x in outliers_count)
print('total outlier columns: ', totalOut)

# Seleccionar las 10 columnas con mas valores atipicos
top_outlier_cols = outliers_count.sort_values(ascending=False).head(10).index.tolist()

outliers_count.sort_values(ascending=False).index.tolist()
print(len(outliers_count.sort_values(ascending=False).index.tolist()))

plt.figure(figsize=(15, 8))
for i, col in enumerate(top_outlier_cols):
    plt.subplot(2, 5, i + 1)  
    sns.violinplot(y=df[col], color="skyblue")
    plt.title(f"{col}")

plt.tight_layout()
plt.show()
# Out:
# total outlier columns:  11
# 15

# %% [markdown]
# ### Low Grade Outliers

# %%
df['highGrade']=targets['highGrade']
df=df[df['highGrade']==False]
df.drop(columns=['highGrade'], inplace=True)
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
multiplier=8
outliers_count = ((df < (Q1 - multiplier* IQR)) | (df > (Q3 + multiplier* IQR))).sum()

totalOut = sum(x > 0 for x in outliers_count)
print('total out: ', totalOut)

# Seleccionar las 10 columnas con mas valores atipicos
top_outlier_cols = outliers_count.sort_values(ascending=False).head(10).index.tolist()

outliers_count.sort_values(ascending=False).index.tolist()
print(len(outliers_count.sort_values(ascending=False).index.tolist()))

plt.figure(figsize=(15, 8))
for i, col in enumerate(top_outlier_cols):
    plt.subplot(2, 5, i + 1)  
    sns.violinplot(y=df[col], color="skyblue")
    plt.title(f"{col}")

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_17153/3208747073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['highGrade'], inplace=True)
# total out:  2
# 15

# %% [markdown]
# ### High Grade Outliers

# %%
df=df_cp.copy()
df['highGrade']=targets['highGrade']
df=df[df['highGrade']==True]
df.drop(columns=['highGrade'], inplace=True)
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
multiplier=8
outliers_count = ((df < (Q1 - multiplier* IQR)) | (df > (Q3 + multiplier* IQR))).sum()

totalOut = sum(x > 0 for x in outliers_count)
print('total out: ', totalOut)

# Seleccionar las 10 columnas con mas valores atipicos
top_outlier_cols = outliers_count.sort_values(ascending=False).head(10).index.tolist()

outliers_count.sort_values(ascending=False).index.tolist()
print(len(outliers_count.sort_values(ascending=False).index.tolist()))

plt.figure(figsize=(15, 8))
for i, col in enumerate(top_outlier_cols):
    plt.subplot(2, 5, i + 1)  
    sns.violinplot(y=df[col], color="skyblue")
    plt.title(f"{col}")

plt.tight_layout()
plt.show()
# Out:
# total out:  1
# 15

# %%
df=df_cp.copy()
df['highGrade']=targets['highGrade']

# %%
df = df.loc[:, df.nunique() > 1]
df
# Out:
#           Maximum/Image-original/diagnostics  \
# Id
# 0.783201                               237.0
# 0.729412                               253.0
# 0.662097                               270.0
# 0.782308                               314.0
# 0.585369                               981.0
# ...                                      ...
# 0.774391                               277.0
# 0.720461                               325.0
# 0.601364                              1411.0
# 0.729605                               604.0
# 0.699646                              1108.0
#
#           VoxelNum/Mask-original/diagnostics  \
# Id
# 0.783201                                1260
# 0.729412                                2685
# 0.662097                                3244
# 0.782308                                1840
# 0.585369                                1692
# ...                                      ...
# 0.774391                                1889
# 0.720461                                3652
# 0.601364                                6199
# 0.729605                                7085
# 0.699646                               12171
#
#           VolumeNum/Mask-original/diagnostics  Energy/firstorder/original  \
# Id
# 0.783201                                    1                1.115748e+07
# 0.729412                                    1                3.206621e+07
# 0.662097                                    1                5.772904e+07
# 0.782308                                    1                5.558937e+07
# 0.585369                                    1                5.079416e+08
# ...                                       ...                         ...
# 0.774391                                    1                2.601654e+07
# 0.720461                                    1                7.703724e+07
# 0.601364                                    1                3.315145e+09
# 0.729605                                    1                7.963674e+08
# 0.699646                                    1                3.742599e+09
#
#           TotalEnergy/firstorder/original  Idn/glcm/original  \
# Id
# 0.783201                     1.115748e+07           0.935386
# 0.729412                     3.206621e+07           0.934436
# 0.662097                     5.505470e+07           0.934934
# 0.782308                     4.038406e+07           0.951514
# 0.585369                     1.705622e+09           0.949190
# ...                                   ...                ...
# 0.774391                     2.481130e+07           0.946634
# 0.720461                     7.946346e+07           0.942016
# 0.601364                     1.113196e+10           0.967871
# 0.729605                     2.468428e+09           0.966738
# 0.699646                     4.909106e+09           0.978241
#
#           LargeDependenceHighGrayLevelEmphasis/gldm/original  \
# Id
# 0.783201                                         652.826984
# 0.729412                                         611.548231
# 0.662097                                         660.159679
# 0.782308                                        1143.141304
# 0.585369                                        3356.104019
# ...                                                     ...
# 0.774391                                         914.722605
# 0.720461                                        1141.659639
# 0.601364                                        9096.525085
# 0.729605                                        1863.377417
# 0.699646                                       12246.326103
#
#           SmallDependenceLowGrayLevelEmphasis/gldm/original  \
# Id
# 0.783201                                           0.006669
# 0.729412                                           0.009179
# 0.662097                                           0.008074
# 0.782308                                           0.006239
# 0.585369                                           0.001814
# ...                                                     ...
# 0.774391                                           0.005010
# 0.720461                                           0.009901
# 0.601364                                           0.000652
# 0.729605                                           0.004621
# 0.699646                                           0.000532
#
#           GrayLevelNonUniformity/glrlm/original  \
# Id
# 0.783201                             158.590584
# 0.729412                             293.777441
# 0.662097                             435.126064
# 0.782308                             158.487887
# 0.585369                             149.244465
# ...                                         ...
# 0.774391                             218.499407
# 0.720461                             336.608660
# 0.601364                             434.953676
# 0.729605                             336.479787
# 0.699646                             425.881185
#
#           RunLengthNonUniformity/glrlm/original  \
# Id
# 0.783201                             175.099687
# 0.729412                             546.590764
# 0.662097                             961.241702
# 0.782308                             273.906764
# 0.585369                             696.367524
# ...                                         ...
# 0.774391                             273.046673
# 0.720461                             778.238077
# 0.601364                            2394.525537
# 0.729605                            1410.298294
# 0.699646                            2976.089706
#
#           GrayLevelNonUniformity/glszm/original  ZoneEntropy/glszm/original  \
# Id
# 0.783201                              17.388889                    4.696937
# 0.729412                              50.100719                    5.422075
# 0.662097                              85.296015                    5.453404
# 0.782308                              27.150943                    5.047446
# 0.585369                              44.787419                    5.763565
# ...                                         ...                         ...
# 0.774391                              26.022901                    5.046687
# 0.720461                              65.146868                    5.347434
# 0.601364                             126.697412                    6.406543
# 0.729605                              58.675963                    6.840655
# 0.699646                              79.179894                    7.331360
#
#           Coarseness/ngtdm/original  y.BoundingBox/Mask-original/diagnostics  \
# Id
# 0.783201                   0.007719                                    138.0
# 0.729412                   0.004074                                    112.0
# 0.662097                   0.002515                                    104.0
# 0.782308                   0.006769                                    150.0
# 0.585369                   0.006528                                    181.0
# ...                             ...                                      ...
# 0.774391                   0.005374                                    108.0
# 0.720461                   0.003218                                     61.0
# 0.601364                   0.002340                                    137.0
# 0.729605                   0.003548                                    126.0
# 0.699646                   0.003712                                    152.0
#
#           y.CenterOfMassIndex/Mask-original/diagnostics  highGrade
# Id
# 0.783201                                     161.988889       True
# 0.729412                                     149.808566       True
# 0.662097                                     152.673859       True
# 0.782308                                     171.559783       True
# 0.585369                                     202.115248       True
# ...                                                 ...        ...
# 0.774391                                     132.161461      False
# 0.720461                                     101.386911      False
# 0.601364                                     188.893209       True
# 0.729605                                     186.333945      False
# 0.699646                                     241.988579       True
#
# [128 rows x 16 columns]

# %%
import pandas as pd
# Función para detectar y tratar outliers utilizando el IQR
def tratar_outliers_iqr(df, multiplier=8):
    # Selecciona solo las columnas numéricas
    num_cols = df.select_dtypes(include=['float64', 'int64']).columns

    for col in num_cols:
        # Calcular Q1 (primer cuartil), Q3 (tercer cuartil) y IQR
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1

        # Definir límites inferior y superior para los outliers
        lower_bound = Q1 - multiplier * IQR
        upper_bound = Q3 + multiplier* IQR

        # Imprimir los límites de cada columna
        #print(f"{col}: Limite inferior={lower_bound}, Limite superior={upper_bound}")

        # Reemplazar los valores por los límites (capping)
        df[col] = df[col].apply(lambda x: upper_bound if x > upper_bound else (lower_bound if x < lower_bound else x))

    return df

# Aplicar la función para tratar los outliers en el DataFrame
df = tratar_outliers_iqr(df)

# %%
df.to_csv('processedFlair.csv', index=True)

# %%
import pandas as pd
import numpy as np
from scipy import stats
from sklearn.preprocessing import LabelEncoder

# Function to calculate Cohen's d for numerical columns
def cohens_d(group1, group2):
    mean_diff = group1.mean() - group2.mean()
    pooled_std = np.sqrt(((group1.shape[0]-1)*(group1.std()**2) + (group1.shape[0]-1)*(group2.std()**2)) / (group1.shape[0]+group2.shape[0]-2))
    return np.abs(mean_diff / pooled_std)


high_graders = df[df['highGrade'] == True]
low_graders = df[df['highGrade'] == False]

differences = []


for column in df.columns:
    if column == 'highGrade':
        continue

    # Calculate Cohen's d for numerical columns
    d = cohens_d(high_graders[column], low_graders[column])
    differences.append((column, d, 'numerical'))


# Convert to DataFrame and sort by difference score
diff_df = pd.DataFrame(differences, columns=['Column', 'Difference', 'Type'])
top_10 = diff_df.sort_values(by='Difference', ascending=False).head(30)

# Print results
print("Top 10 columns with largest differences between highGraders and lowGraders:")
print(top_10[['Column', 'Difference', 'Type']])
# Out:
# Top 10 columns with largest differences between highGraders and lowGraders:
#                                                Column  Difference       Type
# 14      y.CenterOfMassIndex/Mask-original/diagnostics    0.465312  numerical
# 13            y.BoundingBox/Mask-original/diagnostics    0.414888  numerical
# 9               RunLengthNonUniformity/glrlm/original    0.374059  numerical
# 7   SmallDependenceLowGrayLevelEmphasis/gldm/original    0.350334  numerical
# 10              GrayLevelNonUniformity/glszm/original    0.342483  numerical
# 3                          Energy/firstorder/original    0.340941  numerical
# 12                          Coarseness/ngtdm/original    0.312073  numerical
# 8               GrayLevelNonUniformity/glrlm/original    0.311097  numerical
# 6   LargeDependenceHighGrayLevelEmphasis/gldm/orig...    0.302397  numerical
# 4                     TotalEnergy/firstorder/original    0.278149  numerical
# 1                  VoxelNum/Mask-original/diagnostics    0.275115  numerical
# 0                  Maximum/Image-original/diagnostics    0.274544  numerical
# 11                         ZoneEntropy/glszm/original    0.274464  numerical
# 5                                   Idn/glcm/original    0.236022  numerical
# 2                 VolumeNum/Mask-original/diagnostics         NaN  numerical
# /tmp/ipykernel_17153/2759210152.py:10: RuntimeWarning: invalid value encountered in scalar divide
#   return np.abs(mean_diff / pooled_std)
